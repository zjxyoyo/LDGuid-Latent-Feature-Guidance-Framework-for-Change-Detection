# %%
# uncomment this to install 
# %pip install -e .

# %% [markdown]
# # Step 1: Download Dataset

# %%
# %run data/load_data.py
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Datasets were loaded and cached successfully, happy training 😊

# %% [markdown]
# # Step 2: Train the model

# %%
# uncomment this to train
# %run src/train/train.py

# %% [markdown]
# # Step 3: Visualize Sample

# %%
# %run visualize_sample.py
# Out:
# Adjust the loop below to print the sample you want
# cpu
# Checkpoint loaded successfully.
